# %%
import numpy as np
from scipy import ndimage
from scipy import misc

# %%
mapache = misc.face()
mapache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
#         ...,
#         [120, 156,  95],
#         [119, 155,  93],
#         [118, 154,  92]]], dtype=uint8)

# %%
mapache.shape
# Out:
# (768, 1024, 3)

# %%
type(mapache)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(mapache)

# %%
# girar mapache
plt.imshow(mapache[::-1])

# %%
# dividir en 2

plt.imshow(mapache ** 2)

# %%
# 1 seleccionar cara del mapache

plt.imshow(mapache[0:500, 500:800], cmap=plt.cm.gray)

# %%
# 2 desenfoque


desenfoque_mapache = ndimage.gaussian_filter(mapache, sigma=5)
plt.imshow(desenfoque_mapache)

# %%
# 3 Filtro azul sobre la imagen
plt.imshow(mapache[:,:,2],vmin=0,vmax=1620)

# %%
# 4 filtro rojo
mapache_rojo=np.copy(mapache)
mapache_rojo[:,:,1]=0
mapache_rojo[:,:,2]=0
plt.imshow(mapache_rojo)

# %%
# flip de la imagen (espejo)

flip_mapache = np.flipud(mapache)
plt.imshow(flip_mapache)

# %%
# 5 rotar mapache 45 y 90 grados
rota45 = ndimage.rotate(mapache, 45)
plt.imshow(rota45)

rota90 = ndimage.rotate(mapache, 90)
plt.imshow(rota90)
